# %% [markdown]
# # Storing Datas with Local Storage

# %% [markdown]
# ### 3 main type of storage
#
# * Cookies
# * Session Storage
# * Local Storage

# %%
var name = prompt("enter your first name: ");

// This can be stored as a key: vaule pair in local storage
// 'name': 'David'

# %%
// the js keyword to store data
localStorage.setItem("key", "vaule");

# %%
//reterive and store data in a varibke with Key:Value relationship

var fName = prompt("enter your first name: ");

localStorage.setItem("user", fName);

// to retrive the data in is in local storage

var retriveName = localStorage.getItem("user");
var retriveName = localStorage.user;
